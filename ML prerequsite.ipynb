# %% [markdown]
# Question1:

# %% [markdown]
# The multiplication of (n,k) and (k,m) matrix is a (n,m) matrix. So, the each element of the resultant matrix has k multiplications and (k-1) additions.
# So, total no. of multiplications are n*m*k and additions are n*m*(k-1)

# %% [markdown]
# Question2:

# %%
import numpy as np
import timeit
A = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
B = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]
result = [[0,0,0],
         [0,0,0],
         [0,0,0]]
def matrix_list(A,B):
    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]
    return result
def matrix_numpy(A,B):
    mat = np.dot(A,B)
    return mat


list_time = timeit.timeit(lambda: matrix_list(A,B), number=100000)
numpy_time = timeit.timeit(lambda: matrix_numpy(A,B), number=100000)

print('Time for matrix multiplication using List:',list_time)
print('Time for matrix multiplication using numpy:',numpy_time)

#Because NumPy arrays are kept in memory continuously, as opposed to lists, processes can access and work with them with great efficiency.
# Out:
# Time for matrix multiplication using List: 0.398106100037694
# Time for matrix multiplication using numpy: 0.3290958001744002

# %% [markdown]
# Question4:

# %%
The gradient of func with respect to x: 2xy+(y^3)cos(x)
The gradient of func with respect to y: (x^2)+3(y^2)⋅sin(x)

# %% [markdown]
# Question5:

# %%
import jax
import jax.numpy as jnp
import random
def f(x, y):
    return x**2 * y + y**3 * jnp.sin(x)
    
grad_fx = jax.grad(f, argnums=0)
grad_fy = jax.grad(f, argnums=1)

# randx = jnp.random.rand()
# randy = jnp.random.rand()
rand_x = 3.0
rand_y = 4.0
analy_grad_x = 2 * rand_x * rand_y + rand_y**3 * jnp.cos(rand_x)
analy_grad_y = rand_x**2 + 3 * rand_y**2 * jnp.sin(rand_x)

jax_grad_x = grad_fx(rand_x, rand_y)
jax_grad_y = grad_fy(rand_x, rand_y)

print("Gradients match with respect to x:", jnp.allclose(analy_grad_x, jax_grad_x))
print("Gradients match with respect to y:", jnp.allclose(analy_grad_y, jax_grad_y))
# Out:
# Gradients match with respect to x: True
# Gradients match with respect to y: True

# %% [markdown]
# Question6:

# %%
import sympy as sp
x, y = sp.symbols('x y')
f = x**2 * y + y**3 * sp.sin(x)
grad_x = sp.diff(f, x)
grad_y = sp.diff(f, y)
print("Analytical Gradient with respect to x:", grad_x)
print("Analytical Gradient with respect to y:", grad_y)
# Out:
# Analytical Gradient with respect to x: 2*x*y + y**3*cos(x)
# Analytical Gradient with respect to y: x**2 + 3*y**2*sin(x)

# %% [markdown]
# Question7:

# %%
Records = {
    2022: {
        'Branch 1': {
            'Roll Number 1': {
                'Name': 'N',
                'Marks': {
                    'Maths': 100,
                    'English': 70,
                }
            },
        },
        'Branch 2': {
        },
    },
    2023: {
        'Branch 1': {},
        'Branch 2': {},
    },
    2024: {
        'Branch 1': {},
        'Branch 2': {},
    },
    2025: {
        'Branch 1': {},
        'Branch 2': {},
    }
}
print(Records)
# Out:
# {2022: {'Branch 1': {'Roll Number 1': {'Name': 'N', 'Marks': {'Maths': 100, 'English': 70}}}, 'Branch 2': {}}, 2023: {'Branch 1': {}, 'Branch 2': {}}, 2024: {'Branch 1': {}, 'Branch 2': {}}, 2025: {'Branch 1': {}, 'Branch 2': {}}}

# %% [markdown]
# Question9:

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = x
x_values = np.arange(0.5, 100.5, 0.5)
y_values = x_values

plt.plot(x_values, y_values, label='y = x')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = x**2
x_values = np.arange(0.5, 100.5, 0.5)
y_values = x_values**2

plt.plot(x_values, y_values, label='y = x**2')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x**2')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = x**3/100
x_values = np.arange(0.5, 100.5, 0.5)
y_values = x_values**3/100

plt.plot(x_values, y_values, label='y = x**3/100')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x**3/100')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = sin(x)
x_values = np.arange(0.5, 100.5, 0.5)
y_values = np.sin(x_values)

plt.plot(x_values, y_values, label='y = np.sin(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = np.sin(x)')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = sin(x)/x
x_values = np.arange(0.5, 100.5, 0.5)
y_values = np.sin(x_values)/x_values

plt.plot(x_values, y_values, label='y = np.sin(x)/x')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = np.sin(x)/x')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = log(x)
x_values = np.arange(0.5, 100.5, 0.5)
y_values = np.log(x_values)

plt.plot(x_values, y_values, label='y = np.log(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = np.log(x)')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#for y = x
x_values = np.arange(0.5, 100.5, 0.5)
y_values = np.exp(x_values)

plt.plot(x_values, y_values, label='y = np.exp(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = np.exp(x)')

plt.legend()
plt.show()

# %% [markdown]
# Question10:

# %%
import numpy as np
import pandas as pd

random_matrix = np.random.uniform(1, 2, size=(20, 5))

df = pd.DataFrame(random_matrix, columns=['a', 'b', 'c', 'd', 'e'])

highest_std_colm = df.std().idxmax()

lowest_mean_row = df.mean(axis=1).idxmin()

print("DataFrame:")
print(df)
print("\nColumn with the highest standard deviation:", highest_std_colm)
print("Row with the lowest mean:", lowest_mean_row)
# Out:
# DataFrame:
#            a         b         c         d         e
# 0   1.191572  1.456986  1.645160  1.904172  1.028259
# 1   1.826849  1.886133  1.084631  1.911489  1.400839
# 2   1.042458  1.521193  1.933016  1.957288  1.312031
# 3   1.198773  1.249589  1.096772  1.035852  1.530627
# 4   1.676537  1.146515  1.536935  1.470250  1.086424
# 5   1.508532  1.775395  1.749453  1.745310  1.084417
# 6   1.487057  1.622660  1.557564  1.132643  1.310188
# 7   1.834230  1.643034  1.767390  1.996255  1.356499
# 8   1.785470  1.328578  1.321170  1.936679  1.009150
# 9   1.763741  1.847146  1.169734  1.089356  1.948254
# 10  1.748636  1.704160  1.878691  1.440662  1.176422
# 11  1.688847  1.645665  1.716429  1.410843  1.687044
# 12  1.621098  1.345302  1.778405  1.295366  1.673384
# 13  1.778760  1.554758  1.022894  1.508493  1.560050
# 14  1.064468  1.110708  1.411887  1.851403  1.962289
# 15  1.635599  1.855802  1.296721  1.151758  1.188617
# ...

# %% [markdown]
# Question12:

# %%
import numpy as np

A = np.array([[12, 56, 34], [47, 54, 56]])
B = np.array([44, 78, 58])

result = A/B

print("Array A:\n", A )
print("\nArray B:\n",B)
print("\nResult of Broadcasting (A + B):\n", result)
# Out:
# Array A:
#  [[12 56 34]
#  [47 54 56]]
#
# Array B:
#  [44 78 58]
#
# Result of Broadcasting (A + B):
#  [[0.27272727 0.71794872 0.5862069 ]
#  [1.06818182 0.69230769 0.96551724]]

# %% [markdown]
# Question13:

# %%
import numpy as np

def f_argmin(arr):
    lowest_value = float('inf')
    highest_index = None
    for i, value in enumerate(arr):
        if value < min_value:
            min_value = value
            min_index = i
    return min_index

arr = np.array([4, 2, 8, 1, 6])
result_func = f_argmin(arr)
result_np = np.argmin(arr)

print("Function argmin result:", result_func)
print("np.argmin result:", result_np)
